# %% [markdown]
# Instalar librerías

# %%
# !pip install fastapi uvicorn pyngrok
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 6.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# Usando FastAPI

# %%
from fastapi import FastAPI
app = FastAPI()

@app.get("/")
def read_root():
    return {"mensaje: Hola, mundo!"}

@app.get("/items/{item_id}")
def read_item(item_id: int, q: str = None):
    return {"item_id": item_id, "q": q}

# %% [markdown]
# Cuenta ngrok

# %%
# !ngrok config add-authtoken 2rfEjRbq4wuJiG5kkJ8yr1d6hV6_4q11B2MCVn73HpRdEj1kS
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %% [markdown]
# Ejecutar el servidor

# %%
from pyngrok import ngrok
import uvicorn
import threading

# Crear túnel con ngrok
public_url = ngrok.connect(8000)
print(f"Public URL: {public_url}")

# Ejecutar FastAPI en segundo plano
def run():
    uvicorn.run(app, host="0.0.0.0", port=8000)

thread = threading.Thread(target=run)
thread.start()
# Out:
# Public URL: NgrokTunnel: "https://e151-34-55-204-230.ngrok-free.app" -> "http://localhost:8000"

# %% [markdown]
# Detener el servidor

# %%
ngrok.disconnect(public_url)
print("Tunel ngrok desconectado")
ngrok.kill()
print("Todos los túneles ngrok han sido cerrados")
# Out:
# Tunel ngrok desconectado
# Todos los túneles ngrok han sido cerrados

# %% [markdown]
# Configuración Github

# %%
# !git config --global user.name "vicogarcia16"
# !git config --global user.email "mg_619@hotmail.com"

# %%
# !git clone https://github.com/vicogarcia16/fastapi_colab_test.git
# Out:
# Cloning into 'fastapi_colab_test'...
# ...

# %%
# !cp  /content/fastapi_colab_test/
# Out:
# cp: cannot stat '/content/drive/MyDrive/Colab': No such file or directory
# cp: cannot stat 'Notebooks/fastapi_test.ipynb': No such file or directory
